# %% [markdown]
# <a href="https://colab.research.google.com/github/devabhaktuni/MLProject/blob/main/minor_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data images

# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("pretty sunflower",limit=30,output_dir='images',adult_filter_off=True)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://preppywallpapers.com/wp-content/uploads/2019/08/Sunflower-iPhone-Wallpapers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://garden.org/pics/2015-05-31/phoebesviolets/a9098c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://garden.org/pics/2013-12-19/Newyorkrita/38d0cc.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/e1/05/83/e10583609e9b146022a51f34ced98536.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://4.bp.blogspot.com/-EvQYk5Z2ISQ/TV1Y6C9VAlI/AAAAAAAAADA/0PviOUYUjU8/s1600/Sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.pinimg.com/736x/23/69/63/23696333831560e5a3853af4d191ff6b--pretty-flowers-sunflowers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://i.pinimg.com/originals/bf/43/c1/bf43c1a18bb9ca4ec14b4eb555d1fed4.jpg
# ...

# %%
from bing_image_downloader import downloader
downloader.download("rugby ball leather",limit=30,output_dir='images',adult_filter_off=True)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn.shopify.com/s/files/1/0788/5979/products/mvp-leather-balls-heritage-leather-rugby-ball-2_2048x.jpg?v=1550134680
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.shopify.com/s/files/1/0788/5979/products/mvp-leather-balls-heritage-leather-rugby-ball-1_2356x.jpg?v=1550134680
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.shopify.com/s/files/1/0788/5979/products/mvp-leather-balls-brown-cream-leather-rugby-ball-1_2048x.jpg?v=1550134649
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.notonthehighstreet.com/fs/66/7f/caf0-7c5a-45fa-a436-44b52ec027a6/original_ram-rugby-vintage-leather-rugby-ball.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.webbellisrugby.co.uk/wp-content/uploads/2016/04/leather-rugby-ball-puntabout.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("ice cream cone",limit=30,output_dir='images',adult_filter_off=True)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://graphics8.nytimes.com/images/2013/06/02/magazine/02wmt/02wmt-superJumbo-v3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://bostononbudget.com/wp-content/uploads/2015/05/Friendlys-Ice-Cream-Cone.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://shewearsmanyhats.com/wp-content/uploads/2013/07/dipped-ice-cream-cones-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.braums.com/wp-content/uploads/2018/06/IceCreamCones.jpg
# [Error]Invalid image, not saving https://www.braums.com/wp-content/uploads/2018/06/IceCreamCones.jpg
#
# [!] Issue getting: https://www.braums.com/wp-content/uploads/2018/06/IceCreamCones.jpg
# [!] Error:: No active exception to reraise
# ...

# %%
import numpy as np
a=np.array([[1,2,3,4,5],[4,5,6,7,8]])
a.ndim
# Out:
# 2

# %%
#how do i convert matrix to vector? -flatten()
a.flatten()
# Out:
# array([1, 2, 3, 4, 5, 4, 5, 6, 7, 8])

# %%
#preprocessing
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from skimage.io import imread
from skimage.transform import resize
target=[]
images=[]
flat_data=[]
DATADIR='/content/images'
CATEGORIES=['pretty sunflower','rugby ball leather','ice cream cone']
for category in CATEGORIES:
 print(category)
# Out:
# pretty sunflower
# rugby ball leather
# ice cream cone

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread
from skimage.transform import resize
target=[]
images=[]
flat_data=[]
DATADIR='/content/images'
CATEGORIES=['pretty sunflower','rugby ball leather','ice cream cone']
for category in CATEGORIES:
  class_num=CATEGORIES.index(category)
  print(class_num)
# Out:
# 0
# 1
# 2

# %%
for category in CATEGORIES:
  class_num=CATEGORIES.index(category)
  path=os.path.join(DATADIR,category)
  print(path)
# Out:
# /content/images/pretty sunflower
# /content/images/rugby ball leather
# /content/images/ice cream cone

# %%
for category in CATEGORIES:
  class_num=CATEGORIES.index(category)
  path=os.path.join(DATADIR,category)
  for img in os.listdir(path): 
     img_array=imread(os.path.join(path,img))
    # print(img_array.shape)
     plt.imshow(img_array)

# %%
for category in CATEGORIES:
  path=os.path.join(DATADIR,category)
  for img in os.listdir(path): 
     img_array = imread(os.path.join(path,img))
     img_resized = resize(img_array,(150,150,3))
     print(img_resized.shape)
# Out:
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# (150, 150, 3)
# ...

# %%
type(img_array)
# Out:
# numpy.ndarray

# %%
type(img_resized)
# Out:
# numpy.ndarray

# %%
for category in CATEGORIES:
  class_num=CATEGORIES.index(category)
  path=os.path.join(DATADIR,category)
  for img in os.listdir(path):
    img_array=imread(os.path.join(path,img))
    img_resized=resize(img_array,(150,150,3))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)
    target.append(class_num)
target 
flat_data=np.array(flat_data)
targat=np.array(target)
images=np.array(images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-aeda327a298f> in <module>()
# ----> 1 for category in CATEGORIES:
#       2   class_num=CATEGORIES.index(category)
#       3   path=os.path.join(DATADIR,category)
#       4   for img in os.listdir(path):
#       5     img_array=imread(os.path.join(path,img))
#
# NameError: name 'CATEGORIES' is not defined

# %%
df= pd.DataFrame(flat_data)
df['Target']=target
df
# Out:
#            0         1         2  ...     67498     67499  Target
# 0   0.137333  0.285098  0.418510  ...  0.023529  0.000000       0
# 1   0.933150  0.929229  0.807660  ...  0.450980  0.356863       0
# 2   0.464453  0.490196  0.564253  ...  0.039216  0.011765       0
# 3   0.996078  0.996078  0.996078  ...  0.164706  0.121569       0
# 4   0.870588  0.643137  0.064706  ...  0.666667  0.215686       0
# ..       ...       ...       ...  ...       ...       ...     ...
# 85  0.996078  0.996078  0.996078  ...  0.996078  0.996078       2
# 86  0.117647  0.109150  0.066667  ...  0.525490  0.324837       2
# 87  0.811765  0.827451  0.843137  ...  0.811765  0.815686       2
# 88  1.000000  1.000000  1.000000  ...  1.000000  1.000000       2
# 89  0.571307  0.586993  0.622288  ...  0.713725  0.728248       2
#
# [90 rows x 67501 columns]

# %%
plt.imshow(images[0])

# %%
plt.imshow(images[0],cmap='Accent')
plt.show()

# %%
unique,count=np.unique(target,return_counts=True)
plt.bar(CATEGORIES,count)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# #split data into training and testing
# from sklearn.model_selection import train_tesx_train,x_test,y_train,y_test=train_test_split(flat_data,target,test_size=0.3,random_state=109)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(flat_data,target,test_size=0.3,random_state=109)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-047b5b1b3ef0> in <module>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(flat_data,target,test_size=0.3,random_state=109)
#
# NameError: name 'target' is not defined

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm
param_grid=[
              {'C':[1,10,100,1000],'kernel':['linear']},
              {'C':[1,10,100,1000],'gamma':[0.001,0.0001],'kernal':['rbf']},
]
svc=svm.SVC(probability=True)
clf=GridSearchCV(svc,param_grid)
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1c11da43363f> in <module>()
#       7 svc=svm.SVC(probability=True)
#       8 clf=GridSearchCV(svc,param_grid)
# ----> 9 clf.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
y_pred=clf.predict(x_test)
y_pred

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_pred,y_test)

# %%
confusion_matrix(y_pred,y_test)

# %%
#save the model using pickle library
import pickle
pickle.dump(clf,open('img_model.p','wb'))

# %%
model=pickle.load(open('img_model.p','rb'))

# %%
#testing a brand new image
flat_data=[]
url = input ('Enter your URL')
img=imread(url)
img_resized=resize(img,(150,150,3))
flat_data.append(img_resized.flatten())
flat_data=np.array(flat_data)
print(img.shape)
plt.imshow(img_resized)
y_out=model.predict(flat_data)
y_out=CATEGORIES[y_out[0]]
print(f'PREDICTED OUTPUT:{y_out}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-592870861399> in <module>()
#       1 #testing a brand new image
#       2 flat_data=[]
# ----> 3 url = input ('Enter your URL')
#       4 img=imread(url)
#       5 img_resized=resize(img,(150,150,3))
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849             self._parent_ident,
#     850             self._parent_header,
# --> 851             password=False,
#     852         )
#     853
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
# ...

# %%
# !pip install streamlit
# !pip install pyngrok
from pyngrok import ngrok
# Out:
# ...
#      |████████████████████████████████| 7.5MB 11.6MB/s
# ...
#      |████████████████████████████████| 112kB 63.8MB/s
# ...
#      |████████████████████████████████| 163kB 62.2MB/s
# ...
#      |████████████████████████████████| 4.6MB 45.1MB/s
# ...
#      |████████████████████████████████| 81kB 6.1MB/s
# ...
#      |████████████████████████████████| 71kB 6.3MB/s
# ...
#      |████████████████████████████████| 122kB 45.1MB/s
# ...
#   Created wheel for blinker: filename=blinker-1.4-cp36-none-any.whl size=13450 sha256=1b7d82b903cda37dd13e0a151c5d6c3ff073ad5564fd2b78147f62abba1d3113
#   Stored in directory: /root/.cache/pip/wheels/92/a0/00/8690a57883956a301d91cf4ec999cc0b258b01e3f548f86e89
# Successfully built blinker
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.5.0 which is incompatible.
# ...
#   Found existing installation: ipykernel 4.10.1
#     Uninstalling ipykernel-4.10.1:
#       Successfully uninstalled ipykernel-4.10.1
# ...
#      |████████████████████████████████| 737kB 11.8MB/s
# ...
